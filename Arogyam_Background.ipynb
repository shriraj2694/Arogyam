    3.659484625, 4.850433708, 2.880721846, 5.22054027, 4.032259504,
    2.768238928, 3.686001324, 3.67043101, 5.198985504, 4.194313129,
    4.172935335, 3.377337638, 4.408513182, 4.205809732, 2.718397734,
    2.951644715, 3.355489791, 4.726845017, 2.095914087
]

# Calculate sand bed area for each turbidity value
sand_bed_areas = []



# Display the results
for turbidity, area in zip(turbidity_values, sand_bed_areas):
    print(f'{area:.2f}')
# Out:
# 13.33
# 20.25
# 13.75
# 20.83
# 18.34
# 11.52
# 12.03
# 19.81
# 16.18
# 19.67
# 16.48
# 18.05
# 15.51
# 19.86
# 21.50
# 19.69
# 19.21
# 20.27
# 10.96
# 11.52
# 18.60
# 16.87
# 24.57
# 20.38
# 21.71
# 23.40
# 18.83
# 18.02
# 17.96
# 27.17
# 22.90
# 12.86
# 22.76
# 14.22
# 22.63
# 17.56
# 15.59
# 13.03
# 13.08
# 19.46
# 15.80
# 19.96
# 23.32
# 21.11
# 20.44
# 18.62
# 14.38
# 18.00
# 19.83
# 16.32
# 13.72
# 11.01
# 16.84
# 17.08
# 17.84
# 21.52
# 17.73
# 20.07
# 19.82
# 18.40
# 17.56
# 17.66
# 17.35
# 20.15
# 18.31
# 23.47
# 22.98
# 20.79
# 15.48
# 16.36
# 17.48
# 18.71
# 23.97
# 17.43
# 20.95
# 22.60
# 16.93
# 16.48
# 10.32
# 15.79
# 22.56
# 16.92
# 16.98
# 13.48
# 18.86
# 16.26
# 22.12
# 15.23
# 22.51
# 11.50
# 19.73
# 15.10
# 14.28
# 9.09
# 16.43
# 24.12
# 21.44
# 22.80
# 16.70
# 13.99
# 16.94
# 21.96
# 22.87
# 17.98
# 21.44
# 17.44
# 15.29
# 24.87
# 17.90
# 17.83
# 23.58
# 19.07
# 16.76
# 12.59
# 17.56
# 25.33
# 20.69
# 15.42
# 14.17
# 27.92
# 17.22
# 20.99
# 18.89
# 12.96
# 16.98
# ...

# %%
#calculations--> sand cost
import math

# Given values
sand_bed_areas = [
    13.33, 20.25, 13.75, 20.83, 18.34, 11.52, 12.03, 19.81, 16.18, 19.67,
    16.48, 18.05, 15.51, 19.86, 21.50, 19.69, 19.21, 20.27, 10.96, 11.52,
    18.60, 16.87, 24.57, 20.38, 21.71, 23.40, 18.83, 18.02, 17.96, 27.17,
    22.90, 12.86, 22.76, 14.22, 22.63, 17.56, 15.59, 13.03, 13.08, 19.46,
    15.80, 19.96, 23.32, 21.11, 20.44, 18.62, 14.38, 18.00, 19.83, 16.32,
    13.72, 11.01, 16.84, 17.08, 17.84, 21.52, 17.73, 20.07, 19.82, 18.40,
    17.56, 17.66, 17.35, 20.15, 18.31, 23.47, 22.98, 20.79, 15.48, 16.36,
    17.48, 18.71, 23.97, 17.43, 20.95, 22.60, 16.93, 16.48, 10.32, 15.79,
    22.56, 16.92, 16.98, 13.48, 18.86, 16.26, 22.12, 15.23, 22.51, 11.50,
    19.73, 15.10, 14.28, 9.09, 16.43, 24.12, 21.44, 22.80, 16.70, 13.99,
    16.94, 21.96, 22.87, 17.98, 21.44, 17.44, 15.29, 24.87, 17.90, 17.83,
    23.58, 19.07, 16.76, 12.59, 17.56, 25.33, 20.69, 15.42, 14.17, 27.92,
    17.22, 20.99, 18.89, 12.96, 16.98, 14.78, 22.74, 19.86, 17.14, 15.97,
    17.16, 14.60, 11.76, 15.98, 18.91, 20.29, 15.60, 15.13, 16.93, 19.30,
    16.06, 16.56, 13.62, 18.71, 15.40, 15.97, 19.88, 20.86, 22.14, 14.41,
    13.17, 21.10, 20.59, 19.88, 16.62, 9.56, 20.00, 15.58, 16.97, 16.74,
    17.00, 20.71, 19.51, 20.85, 12.06, 16.63, 19.59, 23.68, 18.46, 13.08,
    17.80, 14.90, 16.68, 18.99, 20.65, 19.73, 16.00, 16.49, 17.21, 20.77,
    16.47, 21.83, 12.96, 23.49, 18.15, 12.46, 16.59, 16.52, 23.40, 18.87,
    18.78, 15.20, 19.84, 18.93, 12.23, 13.28, 15.10, 21.27, 9.43
]

# Standard rate of sand in Rs/kg
sand_rate = 5  # Rs/kg

# Conversion factor from square feet to square meters
sqft_to_sqm = 0.092903

# Fixed radius for the cylindrical sand filter
radius = 2  # feet

# Calculate the total cost for each sand bed area
sand_filter_costs = []

for area in sand_bed_areas:
    # Assuming a fixed radius, calculate the height of the cylindrical sand bed
    height = area / (2 * math.pi * radius)

    # Calculate the volume of the cylindrical sand bed
    volume = math.pi * radius**2 * height

    # Calculate the total cost
    cost = volume * sand_rate

    # Append to the list
    sand_filter_costs.append(cost)

# Display the results
for area, cost in zip(sand_bed_areas, sand_filter_costs):
    print(f'{cost:.2f}')
# Out:
# 66.65
# 101.25
# 68.75
# 104.15
# 91.70
# 57.60
# 60.15
# 99.05
# 80.90
# 98.35
# 82.40
# 90.25
# 77.55
# 99.30
# 107.50
# 98.45
# 96.05
# 101.35
# 54.80
# 57.60
# 93.00
# 84.35
# 122.85
# 101.90
# 108.55
# 117.00
# 94.15
# 90.10
# 89.80
# 135.85
# 114.50
# 64.30
# 113.80
# 71.10
# 113.15
# 87.80
# 77.95
# 65.15
# 65.40
# 97.30
# 79.00
# 99.80
# 116.60
# 105.55
# 102.20
# 93.10
# 71.90
# 90.00
# 99.15
# 81.60
# 68.60
# 55.05
# 84.20
# 85.40
# 89.20
# 107.60
# 88.65
# 100.35
# 99.10
# 92.00
# 87.80
# 88.30
# 86.75
# 100.75
# 91.55
# 117.35
# 114.90
# 103.95
# 77.40
# 81.80
# 87.40
# 93.55
# 119.85
# 87.15
# 104.75
# 113.00
# 84.65
# 82.40
# 51.60
# 78.95
# 112.80
# 84.60
# 84.90
# 67.40
# 94.30
# 81.30
# 110.60
# 76.15
# 112.55
# 57.50
# 98.65
# 75.50
# 71.40
# 45.45
# 82.15
# 120.60
# 107.20
# 114.00
# 83.50
# 69.95
# 84.70
# 109.80
# 114.35
# 89.90
# 107.20
# 87.20
# 76.45
# 124.35
# 89.50
# 89.15
# 117.90
# 95.35
# 83.80
# 62.95
# 87.80
# 126.65
# 103.45
# 77.10
# 70.85
# 139.60
# ...

# %%
#calculations-->ultrafilteration area
def calculate_membrane_area(flow_rate, concentration, rejection_efficiency=0.85, time=1):
    # Convert flow rate from gallons per minute to cubic meters per second
    flow_rate_cubic_meters_per_second = flow_rate * 0.06309

    # Formula: A = Q * C / (R * t)
    membrane_area = (flow_rate_cubic_meters_per_second * concentration) / (rejection_efficiency * time)
    return membrane_area * 10.764  # Convert square meters to square feet
# Provided concentrations of colloidal silica in mg/l
concentrations = [
    368.5164413, 356.8861356, 310.1357375, 326.6783629, 393.6633955, 303.3097712, 268.6469407,
    404.0416347, 326.6243535, 282.3440505, 299.4157813, 364.4876872, 398.3505168, 335.7544386,
    310.9308583, 326.9439777, 328.3582407, 323.596349, 384.0070058, 304.0019928, 395.3894903,
    307.0117926, 338.3364311, 307.7075086, 387.1753165, 323.8363839, 286.059556, 328.0775332,
    309.0393204, 316.6751618, 385.9756505, 337.3505291, 315.6065944, 307.3525858, 304.5352242,
    317.8829005, 299.8204779, 247.200826, 288.0521917, 339.7519188, 340.3903784, 381.6493229,
    324.8930378, 300.0442343, 348.3594482, 327.6505425, 384.9437789, 374.4335045, 326.9615176,
    349.2692713, 277.5990986, 297.0781535, 300.131272, 344.4423937, 286.5228468, 326.6940179,
    314.7995983, 376.9379723, 311.4526625, 383.6571521, 266.9084283, 350.4452927, 329.178429,
    398.6477857, 377.4045382, 329.2803146, 357.303221, 373.5532353, 304.2831932, 329.2318529,
    341.9872341, 280.6032867, 289.7686966, 320.4214322, 297.2067392, 308.3985155, 329.0397102,
    358.847115, 334.0411862, 348.4081949, 347.9304004, 308.1426389, 332.2393595, 346.4032581,
    426.5435898, 349.1559987, 357.2267095, 358.7247021, 361.9029262, 241.6075323, 307.3970883,
    369.3100078, 369.2642227, 369.5312064, 433.9522119, 362.30018, 326.6623683, 240.9367221,
    320.115497, 275.9082279, 399.5831549, 379.5277063, 319.3067851, 305.8285533, 334.4385388,
    327.118824, 344.1611343, 352.7021822, 338.2138034, 311.598136, 325.9065618, 359.2685426,
    333.1483177, 358.5662821, 297.0093194, 290.2898943, 322.062447, 340.1060278, 343.6358213,
    308.5648863, 384.8553815, 340.2731714, 367.9755579, 328.282029, 277.9517037, 339.9839346,
    384.5648525, 352.3065857, 355.2659229, 267.6368856, 347.0622407, 372.6002964, 292.5158245,
    298.3794584, 340.9836834, 368.8210368, 297.6555749, 348.8681541, 424.7879959, 345.7516385,
    380.576472, 305.7949503, 279.7824004, 319.5764202, 363.0057551, 299.6446114, 312.2470431,
# 159609.22499780002
# 188255.95503578
# 188609.72447264
# 211471.23473212
# 180022.67460582
# 166253.99521136
# 193025.3723602
# 181550.60325556
# 213296.68718708
# 207472.96214484
# 181168.81572742
# 193529.50373498
# 153817.18409928
# 164610.49497896002
# 166302.22267294003
# ...

# %%
import pandas as pd
import math

def calculate_combined_amount_of_carbon(row):
    thm_initial_concentration = row['Trihalomethanes']
    chloramine_initial_concentration = row['Chloramines']
    volume = 1 # litres
    thm_removal_efficiency = 0.90
    chloramine_removal_efficiency = 0.85

    thm_carbon = (thm_initial_concentration * volume) / (1 - thm_removal_efficiency) / 1000
    chloramine_carbon = (chloramine_initial_concentration * volume) / (1 - chloramine_removal_efficiency) / 1000
    combined_carbon = thm_carbon + chloramine_carbon

    return combined_carbon #kg

def calculate_filter_radius(combined_carbon, filter_height):
    # Assuming a cylindrical filter shape
    # Volume = pi * radius^2 * height
    # Solving for radius: radius = sqrt(Volume / (pi * height))
    radius = math.sqrt(combined_carbon / (math.pi * filter_height))
    return radius

def calculate_cost(combined_carbon, cost_per_kg):
    return combined_carbon * cost_per_kg

# Read the CSV file into a DataFrame
df = pd.read_csv('carbondata.csv')

# If 'Volume' column is available, replace 'Volume' with the actual column name for volume
# If 'Volume' column is not available, you may need to provide the volume information in another way

# Constants
filter_height = 2  # in feet
cost_per_kg = 600  # in Rs

# Calculate combined amount of carbon and store in a new column
df['Carbon_req'] = df.apply(calculate_combined_amount_of_carbon, axis=1)

# Calculate filter radius for each 'Carbon_req' value
df['Filter_radius'] = df.apply(lambda row: calculate_filter_radius(row['Carbon_req'], filter_height=filter_height), axis=1)

# Calculate cost for each 'Carbon_req' value
df['Cost'] = df.apply(lambda row: calculate_cost(row['Carbon_req'], cost_per_kg=cost_per_kg), axis=1)

# Display the DataFrame with the new 'Filter_radius' and 'Cost' columns
print("DataFrame with Filter_radius and Cost:")
print(df[['Carbon_req', 'Filter_radius', 'Cost']])
# Out:
# DataFrame with Filter_radius and Cost:
#      Carbon_req  Filter_radius        Cost
# 0      0.918578       0.382356  551.146670
# 1      0.607526       0.310951  364.515441
# 2      0.726040       0.339931  435.624089
# 3      1.057146       0.410183  634.287376
# 4      0.363624       0.240567  218.174356
# ..          ...            ...         ...
# 195    0.315148       0.223958  189.088549
# 196    0.861576       0.370303  516.945400
# 197    0.683424       0.329804  410.054668
# 198    0.618101       0.313646  370.860592
# 199    0.689408       0.331244  413.644755
#
# [200 rows x 3 columns]

# %%
print("Carbon_req values(kg):")
for value in df['Carbon_req']:
    print(value)
# Out:
# Carbon_req values(kg):
# 0.9185777837533335
# 0.6075257353600001
# 0.7260401491200001
# 1.0571456265133334
# 0.3636239271266667
# 0.5994777436600002
# 0.8961249514733336
# 0.6584031475066667
# 0.5913162813866668
# 0.7802806770800002
# 0.8377381626466669
# 0.8189283418066668
# 0.8190480240066668
# 0.8106881117733336
# 0.7368191783266669
# 0.8149134814066668
# 0.6338146779666668
# 0.7606068869400002
# 0.67957451006
# 0.6575239001000001
# 0.5227209377333335
# 0.8094816413733336
# 0.6359351613200002
# 0.9484588360400003
# 0.6363647477000001
# 0.8562846742333335
# 0.3613936218733334
# 0.5480781194733334
# 0.5814175699666668
# 0.5870740683466668
# 0.7553440569066667
# 0.51586998344
# 0.7117448159733334
# 0.49053265266000007
# 0.8973067070133334
# 0.5327870665000001
# 0.7728686618200002
# 0.8565638146333335
# 0.5705126394200002
# 0.34457056184
# 0.4574372390866667
# 0.6490193341800001
# 0.7068073055066668
# 0.7642178949800001
# 0.7006663268666669
# 0.8232575091266667
# 0.9036602714400003
# ...

# %%
print("Radius required(Feet):")
for value in df['Filter_radius']:
    print(value)
# Out:
# Radius required(Feet):
# 0.38235611005807285
# 0.31095132068875775
# 0.3399306967833662
# 0.4101828275629974
# 0.24056713289370213
# 0.3088848429060014
# 0.3776542276407956
# 0.3237099248910177
# 0.30677501383490496
# 0.352399669063938
# 0.36514403952678626
# 0.36102145869266594
# 0.3610478384512368
# 0.359200529362863
# 0.34244476108651123
# 0.3601354033667009
# 0.3176078383834266
# 0.34792865045327814
# 0.32887329243236213
# 0.3234937076698349
# 0.2884330443931327
# 0.3589331477680864
# 0.31813868738337986
# 0.3885253042916916
# 0.31824612363056654
# 0.3691638370670512
# 0.23982823295647307
# 0.29534613915656893
# 0.3041964501118856
# 0.3056726025315995
# 0.3467228581904889
# 0.2865366605815217
# 0.3365675350983624
# 0.2794113391020822
# 0.37790315940817837
# 0.2911970041894411
# 0.35072192387912027
# 0.3692240040578957
# 0.3013302285866739
# 0.2341796493309946
# 0.2698210476500159
# 0.3213948275827689
# 0.3353980865849557
# 0.3487535742975977
# 0.3339378825154039
# ...

# %%
print("Cost required(Rs):")
for value in df['Cost']:
    print(value)
# Out:
# Cost required(Rs):
# 551.1466702520001
# 364.51544121600006
# 435.6240894720001
# 634.2873759080001
# 218.17435627600003
# 359.6866461960001
# 537.6749708840001
# 395.04188850400004
# 354.7897688320001
# 468.1684062480001
# 502.64289758800015
# 491.3570050840001
# 491.42881440400004
# 486.4128670640001
# 442.09150699600013
# 488.94808884400004
# 380.2888067800001
# 456.3641321640001
# 407.744706036
# 394.51434006000005
# 313.6325626400001
# 485.68898482400016
# 381.5610967920001
# 569.0753016240002
# 381.81884862000004
# 513.7708045400001
# 216.83617312400006
# 328.84687168400006
# 348.8505419800001
# 352.2444410080001
# 453.206434144
# 309.521990064
# 427.04688958400004
# 294.31959159600007
# 538.384024208
# 319.6722399
# 463.7211970920001
# 513.9382887800001
# 342.3075836520001
# 206.742337104
# 274.462343452
# 389.4116005080001
# 424.0843833040001
# 458.5307369880001
# 420.39979612000013
# 493.95450547600007
# 542.1961628640001
# 493.11984100000024
# 459.70951918000003
# ...
